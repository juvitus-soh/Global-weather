# %%
import pandas as pd

data = pd.read_csv("/home/leong/Desktop/world weather/GlobalWeatherRepository.csv")

data.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1693301400  2023-08-29 14:00                 28.8
# 1          1693301400  2023-08-29 11:30                 27.0
# 2          1693301400  2023-08-29 10:30                 28.0
# 3          1693301400  2023-08-29 11:30                 10.2
# 4          1693301400  2023-08-29 10:30                 25.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    83.8          Sunny  ...                7.9
# ...

# %%
data.isnull().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# ...

# %%
data.describe()
# Out:
#            latitude     longitude  last_updated_epoch  temperature_celsius  \
# count  18514.000000  18514.000000        1.851400e+04         18514.000000
# mean      19.300429     21.909676        1.697411e+09            20.541855
# std       24.583215     65.702056        2.483708e+06             8.891818
# min      -41.300000   -175.200000        1.693301e+09           -31.000000
# 25%        3.750000     -6.840000        1.695249e+09            15.000000
# 50%       17.250000     23.240000        1.697317e+09            22.300000
# 75%       41.330000     50.580000        1.699473e+09            27.000000
# max       63.830000    179.220000        1.701892e+09            45.400000
#
#        temperature_fahrenheit      wind_mph      wind_kph   wind_degree  \
# count            18514.000000  18514.000000  18514.000000  18514.000000
# mean                68.975408      6.895657     11.099255    161.643945
# std                 16.005882      4.924791      7.926523    105.879847
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Time Series Analysis of Temperature over time
data['last_updated'] = pd.to_datetime(data['last_updated'])
plt.figure(figsize=(24, 12))
sns.lineplot(x='last_updated', y='temperature_celsius', data=data, ci=None)
plt.title('Temperature Over Time')
plt.xlabel('Time')
plt.ylabel('Temperature (Celsius)')
plt.show()
# Out:
# /tmp/ipykernel_18833/3348643375.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='last_updated', y='temperature_celsius', data=data, ci=None)

# %%
#correlation analysis
correlation_matrix = data.corr()
plt.figure(figsize=(24, 16))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
# Out:
# /tmp/ipykernel_18833/3562017510.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
#Wind Speed Distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['wind_kph'], bins=20, kde=True)
plt.title('Wind Speed Distribution')
plt.xlabel('Wind Speed (kph)')
plt.ylabel('Frequency')
plt.show()

# %%
#scatter plot of geospatial analysis
plt.figure(figsize=(10, 8))
sns.scatterplot(x='longitude', y='latitude', hue='temperature_celsius', size='temperature_celsius', data=data)
plt.title('Geospatial Analysis of Temperature')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
# Scatter plot of temperatures against global locations
plt.figure(figsize=(12, 8))
sns.scatterplot(x='longitude', y='latitude', hue='temperature_celsius', size='temperature_celsius', data=data, palette='coolwarm', alpha=0.7)
plt.title('Temperature Across Global Locations')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Temperature (°C)')
plt.show()

# %%
world_map = folium.Map(location=[0, 0], zoom_start=2)

# Add markers for each location with temperature information
for index, row in data.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"Temperature: {row['temperature_celsius']} °C",
        icon=folium.Icon(color='red' if row['temperature_celsius'] > 30 else 'blue')
    ).add_to(world_map)

# Save the map as an HTML file
world_map.save('/path/to/temperature_map.html')
